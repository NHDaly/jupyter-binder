# %%
import tensorflow as tf
import numpy as np
import math
import random

# %% [markdown]
# Load the Data!
# ------------
# Shakespeare's comedies!

# %%
# data I/O
data = open('all_comedies_cat.txt', 'r').read() # should be simple plain text file
#data = "abcdefghijkabcdefghijk"
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 2108622 characters, 69 unique.

# %%
def make_hot_vec(size, t):
    ''' size: a list of dimensions, like is passed to np functions.
        t:    the index to set to 1 (the truth).
    '''
    xs = np.zeros(size) # encode in 1-of-k representation
    xs[0,t] = 1
    return xs
make_hot_vec([1,4], 1)
# Out:
# array([[ 0.,  1.,  0.,  0.]])

# %%
# Hyperparameters -- These control the model's behavior. It's nice to group them so you can
# change them together.
hidden_size = 100
num_steps = 25
learning_rate = 0.01

# This is just for printing our progress.
num_runs_between_logging = 100

# %% [markdown]
# ----------
# Define the Model.
# ------
# This is modelled after Karpathy's minimal RNN, described in his [excellent article](karpathy.github.io/2015/05/21/rnn-effectiveness/) and implemented in this [short gist](https://gist.github.com/karpathy/d4dee566867f8291f086). The basic step function is:
#
# ```
# # update the hidden state
# self.h = np.tanh(np.dot(self.W_hh, self.h) + np.dot(self.W_xh, x))
# # compute the output vector
# y = np.dot(self.W_hy, self.h)
# ```
#
# There are also two biases, `bh` and `by`. So the model has 5 learned parameters: `Wxh`, `Whh`, `Why`, `bh`, and `by`.

# %%
# Define a single step in the RNN from one char to the next
Wxh = tf.Variable(tf.random_uniform([vocab_size, hidden_size], maxval=0.01)) 
Whh = tf.Variable(tf.random_uniform([hidden_size, hidden_size], maxval=0.01))
bh = tf.Variable(tf.zeros([hidden_size]))
Why = tf.Variable(tf.random_uniform([hidden_size, vocab_size], maxval=0.01)) 
by = tf.Variable(tf.zeros([vocab_size]))

# %% [markdown]
# ### Set up the recurrence
#
# This is important: A recurrent neural net is *recurrent* because the simple model is repeated multiple times to create the overall model. This is called "unrolling" the net.
#
# This matters, because in order for backpropogation to calculate the effect that the hidden state has on the loss, it needs to take the changes from one `state` to another into account when calculating the gradient. If you didn't unroll the network, and instead just returned the `state` from each run and passed the `state` back into the next run, the `state`'s only effect on the cost would be how the `state` effected `y`, not how the current `state` effected the next state.
#
# For example, the simple network without unrolling it looks like this:
#
# $  cost = truth - y $, where $ y = W_{hy}*h' $ and $h' = tanh(W_{hh}*h + W_{xh}*x) $
#
# The current state, $h$, only effects $cost$ through it's impact on $y$. Even though it sets the *next state*, $h'$, the transition from $h$ to $h'$ is never considered during backpropogation.
#
# Instead, an *unrolled* network *does* effect the cost both from the current $h$ and on its effect on the next $h$:
#
# $  cost = (truth_1 - y_1) + (truth_0 - y_0) $
#
# for $ y_1 = W_{hy}*h_1 $, $h_1 = tanh(W_{hh}*h_0 + W_{xh}*x_1) $
#
# and
# $ y_0 = W_{hy}*h_0 $, $h_0 = tanh(W_{hh}*h + W_{xh}*x_0) $
#
# Now, $W_{hh}$'s impact on the next $h$ effects the cost just as much as its impact on the current $y$.
#
# SO, I *think*, the more steps you unroll a network for, the more emphasis you're placing on the hidden state's impact versus the other weights.

# %%
inputs = [tf.placeholder(tf.float32, [None, vocab_size]) for _ in xrange(num_steps)]
outputs = {}
hs = {}
hs[-1] = tf.placeholder(tf.float32, [None, hidden_size])
for i in range(len(inputs)):
    hs[i]      = tf.nn.tanh(tf.matmul(inputs[i], Wxh) + tf.matmul(hs[i-1], Whh) + bh)
    outputs[i] = tf.nn.softmax(tf.matmul(hs[i], Why) + by)
print inputs[0], inputs[1], hs[-1], hs[0]
# Out:
# Tensor("Placeholder:0", shape=(?, 69), dtype=float32) Tensor("Placeholder_1:0", shape=(?, 69), dtype=float32) Tensor("Placeholder_25:0", shape=(?, 100), dtype=float32) Tensor("Tanh:0", shape=(?, 100), dtype=float32)

# %%
sess = tf.Session()
# Variables must be initialized by running an `init` Op after having
# launched the graph.  We first have to add the `init` Op to the graph.
init_op = tf.initialize_all_variables()
# Run the 'init' op
sess.run(init_op)

# %% [markdown]
# -----
# Training
# -------
#
# This is the "cross-entropy" algorithm.
# $$
# H_{y'}(y)= −\sum_i y_i' \log(y_i)
# $$
#  $-\log(y_i)$ is useful because it turns percentages into (0,$\infty$) "cost".
# So then I think multiplying by the truth cancels out the percentages for everything else, and summing just turns the one_hot vector into a value?
#
# For example:

# %%
# Implement Cross Entropy:
truths = [tf.placeholder(tf.float32, [None, vocab_size]) for _ in xrange(num_steps)]
cross_entropies = [-tf.reduce_sum(truths[i]*tf.log(outputs[i])) for i in xrange(num_steps)]  # These operations act element-wise.
cross_entropy = tf.add_n(cross_entropies)

# %%
# This was big. I changed the optimizer to the AdagradOptimizer, and upped the learning
#  rate from 0.01 to 0.1.
# I think it's okay to increase the learning rate because Adagrad decreases the rate over time.
train_step = tf.train.AdagradOptimizer(learning_rate).minimize(cross_entropy)

# %% [markdown]
# # Do the thing!

# %%
init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# ## Hallucinating! The fun part!

# %%
def hallucinate(sess, seed_ix, num_chars):
    ix = seed_ix
    ixes = [ix]
    hallucination_h_state = np.zeros([1, hidden_size]) 
    for i in range(num_chars):
        # Create a random starting letter 
        x_in = make_hot_vec([1,vocab_size], ix)

        feed_dict={inputs[0]: x_in}
        feed_dict.update({hs[-1]:hallucination_h_state})

        output, hallucination_h_state = sess.run((outputs[0],hs[0]), feed_dict=feed_dict)
        probs = output[0]
        ix = np.random.choice(range(len(probs)), p=probs)
        ixes.append(ix)
    hallucination=''.join([ix_to_char[ix] for ix in ixes])
    print hallucination

# %% [markdown]
# ## Run it:

# %%
losses = []
iterations = 0
ix = 0
h_state = np.zeros([1, hidden_size])
smooth_loss = -np.log(1.0/vocab_size)*num_steps # loss at iteration 0

# %%
def RunModel():
    global ix,losses,iterations,h_state,smooth_loss
    run = 0
    while True:
        letters=[]
        if ix + num_steps >= len(data):
            break
        input_chars  = [make_hot_vec([1,vocab_size], char_to_ix[ch]) for ch in data[ix:ix+num_steps]]
        target_chars = [make_hot_vec([1,vocab_size], char_to_ix[ch]) for ch in data[ix+1:ix+1+num_steps]]

        feed_dict={inputs[i]: input_chars[i] for i in range(len(input_chars))}
        feed_dict.update({truths[i]: target_chars[i] for i in range(len(target_chars))})
        feed_dict.update({hs[-1]:h_state})

        _, h_state, loss_out = sess.run((train_step, hs[num_steps-1], cross_entropy), feed_dict=feed_dict)

        smooth_loss = smooth_loss * 0.999 + loss_out * 0.001
        # Iterate by 1 or num_steps? I guess by 1 could lead to overfitting?
        ix += num_steps
        #        letters.append(data[ix])
        run += 1
        if run % num_runs_between_logging == 0:   
            iterations += 1
            #        print "train: ", ''.join(letters)
            print "========== Iteration ", iterations, " Loss: ", smooth_loss, " chars ", str(ix)+"/"+str(len(data)), " =============="
            losses.append(smooth_loss)
            hallucinate(sess, random.randint(0,vocab_size-1), 100)
            
RunModel()
# Out:
# ========== Iteration  1  Loss:  104.331752589  chars  2500/2108622  ==============
# q
# Uc,m	diihub.lrogleaea  w :ih  sevtegidmsnAtwIgdooyeenloora,ealL rtw h hnOfusn otso,otsrngrk
# cfdnni
# ========== Iteration  2  Loss:  102.260895394  chars  5000/2108622  ==============
# BzSuAynbU
# trctsai 	au Tah Ioi'
# f r  eitbiur   uoh ibA lTeoh,otoatnedd	o
# emeo ,tydorbha
# lelrtl f;irC
# ========== Iteration  3  Loss:  100.392887013  chars  7500/2108622  ==============
# MdAgmm	mvedri dghl syiB  eiioidg oetonfieuasyhlswdnienicgpedlhUasM
# seicuTo ntUw   Lhnwdeh eh  tnrs  o
# ========== Iteration  4  Loss:  98.7831949926  chars  10000/2108622  ==============
# ero [LAfST Rteal[yr Ok eifi In
# ttiiuocoe
# fAnn
# ghY,.ReHhlhoutndsd hwI	ypsahdeo	ivokacuO)Er hh df e	srm
# ========== Iteration  5  Loss:  97.209314996  chars  12500/2108622  ==============
# U
# y)CCteIe Lopey isato el rub ee
#
#  tr
# i'
# etdl R e	nntwB,Rdh a,rsny  emirsLeRemspgt eeoblt  horNrrtTLo
# ========== Iteration  6  Loss:  95.6776763091  chars  15000/2108622  ==============
# ' s wWeas imOiR utauien  	titOsi aeo- cf
#  hi mA hf lg  etxso ehshHrE kT  t i	aLe uedln ra	tla.,yen
# ec
# ========== Iteration  7  Loss:  94.4166849799  chars  17500/2108622  ==============
# heFtSI adyt.eSm 'sexn	e tN	f,u  	laaih ieeAat ae O wi [ei nh tfhese  aido,s bir,eyi mnormes oek ynhee
# ========== Iteration  8  Loss:  93.0891322937  chars  20000/2108622  ==============
#  G]re o lorh uvL renr   a ee ys rtneaetmUheaata tSrt
# sioehaaa
# eo tahdt ev	nahvhtthecos rE	 m efefsnE
# ========== Iteration  9  Loss:  91.9008261609  chars  22500/2108622  ==============
# F(:eos
# rComshaooec  hduaFmlt g a
# e'r s,eu d t   ls 'e,v,,dsn nrIo
# :swhmu e reirkeAhr h]l IiWostttyrt
# ========== Iteration  10  Loss:  90.7403004076  chars  25000/2108622  ==============
# A[og:uy:ih,rytaur onhSi E s k lr ia
# e seego i Atabnl  faWo
# nse tesj t,l hlr r a:huitoheNbaniNwbeni,aa
# ========== Iteration  11  Loss:  89.8277678099  chars  27500/2108622  ==============
# PteNCpsdnt roas mdhhe hl ueeAt wtSme eno  e  rmaudatoeooueeiorn tte nxrsoghteo d serne t sytf IeinsA
# ========== Iteration  12  Loss:  89.0544681882  chars  30000/2108622  ==============
# ZEk-o]tul ecowtrusisitlel(hioOlasdeyt cW  oho deyrmnheFat ytK m did
# eltteeefotr |eee 	 awTsld'C mo
# u
# ========== Iteration  13  Loss:  88.1334336285  chars  32500/2108622  ==============
# w
# mphhus'ft,reriwneehi,d
# 	siliem t
# ee l ulhhcwee
# apdiltywyrLss,ue d,lW toroadhiutgawdn ycdE te lmmrmn
# ========== Iteration  14  Loss:  87.002847809  chars  35000/2108622  ==============
# kFNqflg-t d,arekt  I
# wafaoc t
#
# S[pGpah-sn,aEemo ir Txtenhmt
# roeominudetnashywa;	lot [l.giE; or,er K
# ========== Iteration  15  Loss:  86.1448776901  chars  37500/2108622  ==============
# 'podlrsfnuatedinhadI  oeiraenoea yeovfs ochlote Inysyg Hne
# ei]tateesse tphtaaottt y  c I'rotivs mooto
# ========== Iteration  16  Loss:  85.5296670009  chars  40000/2108622  ==============
# es-!otptssbsToEwe
# x!,v'rRem non W Rt aawst,eiimaahe s,nes w es ]a
# w'Csra
# l( er l,apde,Oa:d ndO u n e
# ========== Iteration  17  Loss:  84.9568920429  chars  42500/2108622  ==============
# vlUgabocoPmut faew uc Hhetedyy nhts shuh p  ; ud vi utacO t.
# vd !, ltrh nrdrllpgiteish qse '; 	,lt L
# ========== Iteration  18  Loss:  84.0565261486  chars  45000/2108622  ==============
# .m!s|.,e].y
# Ly- aun
# gooldsrg w l. s WaouiTott mmceotnheahsal
# mtteano
# i
# Ka.iTsiy TveIe s   ni leeieh,r
# ========== Iteration  19  Loss:  83.0695198147  chars  47500/2108622  ==============
# 'gote
# yoa wiso
# st;lader ttr kw mat lcmma:oUvaee lhensel,u.hRmloois inv nttny; vosser
# O,Wupvein s, wt
# ========== Iteration  20  Loss:  82.2801772001  chars  50000/2108622  ==============
# det plotrh 	Lh aoaso c
# l pNtau: n soueeeo rouwateh deobui
# Kte,tnlt uon rah yona mle, ? tc
# PPytwl   g
# ========== Iteration  21  Loss:  81.5747615379  chars  52500/2108622  ==============
# RrHfo;E,lpain log nsh.nyyshe so r tirts se: aEh atr	Airnon o ba ioeev laaLw
#
# lLhenvaohe yran, l
# !AIte
# ========== Iteration  22  Loss:  80.8817017463  chars  55000/2108622  ==============
# q]Iddlybte 	sr sednl taonecipean:
# :rr tr tysfunr ,oynile,, eh kkiret tse ooahpatluroac'dh lwto	 Iroti
# ========== Iteration  23  Loss:  80.4201259351  chars  57500/2108622  ==============
# thinkeeoyeg y hIeeooen leerltv tfkmof c gga,eklriyeup rm ahhiterhi e fdv;abiK, uit le pgncwrloe g h h
# ========== Iteration  24  Loss:  79.6187557774  chars  60000/2108622  ==============
# Icms iof now sdt t nosehar?m cstote vnr br
# 	TTime yef sh wihanose wat nhater tort.iwatopan
# u 	geeusrw
# ========== Iteration  25  Loss:  79.1163542507  chars  62500/2108622  ==============
# CNkjOoa r delds the rossty oon ?notauna tk on ta y u utyn knio-nr il nie tounr s  uyeetotat cam da ds
# ========== Iteration  26  Loss:  78.5057018282  chars  65000/2108622  ==============
# TN-BcNp se qe,elh wgltponnarrb ust h. sh ;ylshyvake'nenoaanle
# mosoadrthsiv
# tkwe is; mgllikE t ng da,
# ========== Iteration  27  Loss:  77.8918196214  chars  67500/2108622  ==============
# Nce,, ?hhiri ms, se
# nul,lhas lne erem Tt nel 'o?
#
# mhy fhisladne nh s's gsakraui a neten
# 	Tts mhhh tg,
# ========== Iteration  28  Loss:  77.4144389921  chars  70000/2108622  ==============
#  ye
# TTnByl
# 		ohd rhmmueomdt !Ipho isa, tend nhssH'
#
# CLub]libd t shdeuswvhoeaoloc lr tafe,raru':iliord
# ========== Iteration  29  Loss:  76.8347125164  chars  72500/2108622  ==============
# wresarhemu. ct
# 	roe  de,toy cyee
# SsE		TLl;gle:
# 	TA
# 	Dgg o hhe, thitn s pekllaamRn
#
# Hot|	mrrsfoye nr
# ========== Iteration  30  Loss:  76.3316788353  chars  75000/2108622  ==============
# s-thev an sy ktt wehl  ot
# lshal reGrr f,t ;hsok Iawetarese.ka
# NnB	Lu CBsila o in mord,dc
# 	Iarer soty
# ========== Iteration  31  Loss:  75.9443948069  chars  77500/2108622  ==============
# EaEr;sfdawt a litor ny mny wyhasasosososeeydithe t rhrg !rv a oitine r td womamhe uh, nl wg,mlidkito
# ========== Iteration  32  Loss:  75.51382161  chars  80000/2108622  ==============
# poin lankt,s f.
# 	acanicctamcellg	s syetsee sEnmpr aud qonitdawapibtbiisesn coyerg wiTetl
#
#
# CAOPE		ie
# ========== Iteration  33  Loss:  74.9505806343  chars  82500/2108622  ==============
# bewss nu
# p]sIolhee lpn yhn tns: wovr mfenydyew
# iEss iiue nn,r]omt
#
# N	ELcW
# Iooih  s trete
# wxym
# 	HL
#  h
# ========== Iteration  34  Loss:  74.4724457019  chars  85000/2108622  ==============
# [co; auehelspn tl Wore(ora los-Eyon Iis ud g ieengtr oen'dal tsd, fheerisisire.
#
# N e Iusdeo
# rOWi
#
# SAe
# ========== Iteration  35  Loss:  74.1690963156  chars  87500/2108622  ==============
# Otar	mlp ao haf to iimpgrlm I ,b
#
# WAsed'hbd v wst
#
# FCY w'ng fea anteeY.ksSnor,	Lte eh 	nn'lel pedh;'N
# ========== Iteration  36  Loss:  73.7627738737  chars  90000/2108622  ==============
# pidh dl D tot .i
# dotamus sh wrrec tetsemy
#
#
# Anod t
# tanvu
#
# kI Aifea
# !reN	Wowk	td.ttif 	pbaeed sis rel
# ========== Iteration  37  Loss:  73.232895396  chars  92500/2108622  ==============
# g
# 	Chilivhe nsne ceaa ct y wernooheve. hn p hhe'avey		ve,h nh cowe nhfnka]au nh d slhwoh met
# 	I, vest
# ========== Iteration  38  Loss:  72.7662557448  chars  95000/2108622  ==============
# Ebyektw nater
#
# 	Ud;
# 	nh 	hotosds
#
# RWnLhs fi fescsv nunt te gs unl tuesm eo.sl uh; se 	otn hdn heu
#
# FS
# ========== Iteration  39  Loss:  72.3177910779  chars  97500/2108622  ==============
# ?,imhh cnttesLat
#
# rh
# m terl	wrnye , us teru'et
#  beros uheW mir 	th ttas lse Ieubd Uee; pemttiuhe ch
# ========== Iteration  40  Loss:  72.1682036399  chars  100000/2108622  ==============
# Milse he;mkhoneaeuoi s, tot, gol
# ssimhamse eaitamoe wodd dat panhoaey g sh Ts pillfs-nwunttataei  el
# ========== Iteration  41  Loss:  71.8588328666  chars  102500/2108622  ==============
# [vusttoueatc tongcearcsee, Dh thfehiwe l te h vonyn
# 	Ai nuy w w,	ingsn:m lim fh.yEor Fitu
# titor go fa
# ========== Iteration  42  Loss:  71.3786735178  chars  105000/2108622  ==============
# .?JROFEO
# 	Ao,
#
# NGRRRRLRBNBNTLELTDLjRANAFS
# FLaLLLSWvpo
# shRdfq,ed folidAhaum af
#
# Tou bh  hl, mhat fhet
# ========== Iteration  43  Loss:  71.0788883711  chars  107500/2108622  ==============
# f,voe. Tin e gol gof wint
# 	wo.l	hh eib
# t lonsnr miin rotin u donAreglrito ss afid urkghd,alt hud yim
# ========== Iteration  44  Loss:  70.8614126818  chars  110000/2108622  ==============
# zZsoad sueol 	hhrlvet stedels  ee sisar ahrdpe !namavurarw
# 	ty
#
# 	Na, nr Eitiuorei; ehe bhtvl yesrared
# ========== Iteration  45  Loss:  70.4575602649  chars  112500/2108622  ==============
# et l drsaus s lad iur eysa hs Uedscy tou
# yi? Iast olitr, seaca.
# 	fra ss of tilk au inyp gay 'n ias Mp
# ========== Iteration  46  Loss:  70.1815871613  chars  115000/2108622  ==============
# ],gn	froa w kffife w Ashokd onresusess tte	tos, yo
#
# w-uD Nt LeHeB
# 	Ahor t iutl aash  sf che dlyoc.	lh
# ========== Iteration  47  Loss:  69.9876618402  chars  117500/2108622  ==============
# cont,ese,esuret gor b ra ane	tend	the
# toisrs	Woa
# w, totrm mbapen dide lesihs plesr se.	oootu
#
# Lnxhe
# ========== Iteration  48  Loss:  69.7344597301  chars  120000/2108622  ==============
# -cdir ca.	Aorip uov it,rn wons,coait yar p :euam  henn Sivee piwrd taeshi, Thelsd.
#
# CAU'M	DuAoAaafr n
# ========== Iteration  49  Loss:  69.4592094951  chars  122500/2108622  ==============
# Qn, sihd wlfarr:e
#
# I
# 	SEAPE	[uH.
# LO	[tir mes
# tekud nesvs -hantattee latTinhos so anpas adud ot iemnt
# ========== Iteration  50  Loss:  69.0817159093  chars  125000/2108622  ==============
# Oaort: OItp
# 	Fet
# 	Wer oy nrlavav deed snn ct faneplatgom pes nyoe Iirowasnrted
# 	TE	nhetcilo om trad '
# ========== Iteration  51  Loss:  68.8927135105  chars  127500/2108622  ==============
# IOkMmdnonsh nra-r he tay v techp, bored 'prsbe:t onbdg
# sScIua de mter o'd ivlfiop sl rte f ve thadsd
# ========== Iteration  52  Loss:  68.5355289615  chars  130000/2108622  ==============
# Z[xinoh tSchge mrhe hutsde thlrr lidn I s.
#
# ITU?
# 	LoI yotd ca ame  nef cofimi h nr whg dc ?he Ff ane
# ========== Iteration  53  Loss:  68.207158689  chars  132500/2108622  ==============
# cyhe sat anoropim fhiad cats tyee; mf hor
# torocs wiyd bhlr biy wol n
#
# 	Ohrcuss?;
#
# 	gaum; lhe
# mAnc;S	C
# ========== Iteration  54  Loss:  67.9229984072  chars  135000/2108622  ==============
# -teg-- fe d moleaath.
#
# )]EFFt aonkmhrgn 	ogary pper;fns;
#
# UFyl
#
# 	I Sn
# 	Sy'uoit lhhit ol srpse d,ea mo
# ========== Iteration  55  Loss:  68.1729410223  chars  137500/2108622  ==============
# nugl t, Phar
# 	KN Tounbkc,
# gwait Io houH
# 	Iuwh frisn,:
# T
# LS	Lo Sis hithesod uag Isc rav tiuw w?.
#
# 	AU
# ========== Iteration  56  Loss:  67.8256900417  chars  140000/2108622  ==============
# Q, Whatant yrnp e na
#
# DWataretghe dos po k toe hhese ry amf
# 	[eeh se terd
#
#
#
# HBERRIpHELCAHE T thy ton
# ========== Iteration  57  Loss:  67.5235916307  chars  142500/2108622  ==============
# 	Afthet I yoato; wa;oupn	yirg m hot fmme.	Wposhas sou s, mor stheg he sfueeirintsdflashe to doni veme
# ========== Iteration  58  Loss:  67.2343234914  chars  145000/2108622  ==============
# asadef ioy
# 	Tod yh,l uy nd tond art doul t, list se ketitpr n !hey lrm?
# 	heylir th tsoapamor kn hal y
# ========== Iteration  59  Loss:  66.8776278726  chars  147500/2108622  ==============
# y.cil pedrrlslm
# Tnafotiu se tom on wout autatheutt sndy tot aa?	 lrt an shesl ker, th ns wotd rhertu
# ========== Iteration  60  Loss:  66.5929143581  chars  150000/2108622  ==============
#  gigohenscyeesdils
#
#
# LEEL''Nteorlnthe, tore  hes
# it ou cord nitMviciy oalt dh rroled
#
#
# TDNLwDE	Dhru
# ========== Iteration  61  Loss:  66.4085356916  chars  152500/2108622  ==============
# ?,f[. tug wyhe;. It ou xoni ceru o, yorev laekanps liso 'f uk se souceeert th.
#
# 	Dimesm aw toute
# 	he
# ========== Iteration  62  Loss:  66.1362653084  chars  155000/2108622  ==============
# ;Ete	mon ehe 	rerar
# merl,
# 	(ow tan?
# iAudees yt iy th wounpt id wot ay sicete nht giltelutaft wham l
# ========== Iteration  63  Loss:  66.0169728849  chars  157500/2108622  ==============
#  qw here  sl ye the  afd y
# 	]rele whias weru
# d]
# ECFI Af
# 	SAREeEE
# OTTIord ned Dnuvd pod nriet
# 	Cne,
#
# ========== Iteration  64  Loss:  65.8108543588  chars  160000/2108622  ==============
# DWNE)m;Es Icaveshqmd bur oag unotoframd;
#
# TERNRR
# ONET	Lre wir Pim bhot cikt b nou, h, sorhote syde ah
# ========== Iteration  65  Loss:  65.4776285141  chars  162500/2108622  ==============
# ?Y[ImeH oan wiclo, wf pirutkr: chasr,iw o;t nas ay tor , d nos einn ohatacd tol moin te it iowat sasa
# ========== Iteration  66  Loss:  65.3374469675  chars  165000/2108622  ==============
# TFe? onee thole. barn!w
# 	Iodo-'.
#
# LLIE	Sor!
# 	Bpm wo, tilr wlete hades, shend Irn. hais rouietleseid,m
# ========== Iteration  67  Loss:  65.2886628834  chars  167500/2108622  ==============
# -,y
#
# FINOLDAANELKUAM	OR	TOhiud tlat enle anu agcale tly wim 	s, aowetf pity do sataunugmd be tone dht
# ========== Iteration  68  Loss:  65.0141439686  chars  170000/2108622  ==============
# )LImlmam mpmaun
#
#
# SLRLSS	Nre a tor	sime, atmes wfas samanam, shev rfracs;o igty an 'ov see bres thaft
# ========== Iteration  69  Loss:  64.8603186516  chars  172500/2108622  ==============
# RE	Ypwol yeve
#
# nDrIY	nas l hoos au,gyye ghan mgaurey aonrou toce omouton?	Wu, wibf oc sea't traogkd
#
# ========== Iteration  70  Loss:  64.6947606305  chars  175000/2108622  ==============
# U	Wuel;, Ont iuuncs mas meu.
#
# TDOSI Nnong
# 	PN hec pigror, y oh.
#
# 	LEI c ut OO
#
# S.LOULOL	Inog
# s.dAa	O
# ========== Iteration  71  Loss:  64.5075661833  chars  177500/2108622  ==============
# DzHd dare touse lenthe er if tery ap, th Ie rous
# ssouheu;
# 	Ira we anw feterey Yeo hosoe
# 	Hnp fon sut
# ========== Iteration  72  Loss:  64.4959462861  chars  180000/2108622  ==============
# |ie's batotcev teeu]nml.	Ln ne, Ihinlt mis Wppu 'n dyey io ieled ar?
# 	Ctar tarderf hitor
# sPalA
# 	Eor
# ========== Iteration  73  Loss:  64.3096161246  chars  182500/2108622  ==============
# DKpme cisgk wolr eit inksoll ellarbe fen.
# 	Bn, yh mavl ravhos ohs f:taws loesn hew, lhind peilt pe th
# ========== Iteration  74  Loss:  64.0593520974  chars  185000/2108622  ==============
# Xolhad rraw fhe bobr tordin bapidnthenyrg fithers coe.
#
# YNN
# 	Ar Ie, Ioal d;, thed a? Wfum thonqO
#
# MKa
# ========== Iteration  75  Loss:  63.9441252203  chars  187500/2108622  ==============
# uxowrresdunt.
# 	OYghe ntoy lanneksbn?mlm megafd wnw the fit thors inl;
# 	Tlir mg tonusesdur bad stdeG '
# ========== Iteration  76  Loss:  63.8901283621  chars  190000/2108622  ==============
# At, mus-sgyy de ls thos thete nhergd
#
# JOOEOKMuL
# 	AO Iiol winw
# 	L', c cee thed.
#
# 	R[our Phoro nis,
# 	Is
# ========== Iteration  77  Loss:  63.66066995  chars  192500/2108622  ==============
# &')o'eme or bout oo eraou an toeid, tne kors for anmpt thee, kou thow inlals t ail me the nout er sho
# ========== Iteration  78  Loss:  63.644519342  chars  195000/2108622  ==============
# W
# 	Tor f w-wis aamthe mer
# 	Thet nhes hean  hiB Uot'al ?oud the ipsess.
# 	Slere h
# hit atatlbes bnem'ke
# ========== Iteration  79  Loss:  63.5408208871  chars  197500/2108622  ==============
# pshanress yawdou prfor mest athe t uod  wololn wevlessitoust,
# 	Chinv, oos oud hat de Ohou grund werd
# ========== Iteration  80  Loss:  63.391495565  chars  200000/2108622  ==============
# ts, cenedve ini t ond ]oe wamkreo
# 	Aywo in heale tit she taaksp; usls ah thinsto gatc nevtidfe
# 	 fet
# ========== Iteration  81  Loss:  63.2841399151  chars  202500/2108622  ==============
# !:Q	mo theuy houd
# 	Irelel bou gode	aot mat le matn Vntheyell afo wosot the miulemtelsLsang rau 	wol a
# ========== Iteration  82  Loss:  62.9533069513  chars  205000/2108622  ==============
# Y? minb ouod th mawd ho, shet fnaw hiwtis h ooa he''it cot aass tae.d
#
# CIGLTSOOIN	Ahrt o ullis: fiace
# ========== Iteration  83  Loss:  62.6024414995  chars  207500/2108622  ==============
# Jtptut,
# 	Ihis no t khet bulg, Lamle wase cana?e
# 	anriut Iwdebdsunsen
#
# 	TAEimd cheit an]
#
#
# ROQIN	It
# 	A
# ========== Iteration  84  Loss:  62.6738879069  chars  210000/2108622  ==============
# RVehe mos mote tirinl un aonsg cin li.
#
# LAIM achd thorutpon
# 	thvas s..
# 	AO	Iss co nhere gou to yhaves
# ========== Iteration  85  Loss:  62.8113816695  chars  212500/2108622  ==============
# EUZHET
# SK[um Kygn loo th ma
#
#
#
# D	SReAl Leine bince; t te hw agisd
# 	Oed, wI'I goo bn rintbk tor pfAedi
# ========== Iteration  86  Loss:  62.5858696782  chars  215000/2108622  ==============
# na)nrbon gsa
#
# RUWRELI,AMRENuD	Irecr foon wor; Thonshaas
#
#
# LVLAN Iovte:sh.	war Srha lor s' y co gse mh
# ========== Iteration  87  Loss:  62.5190066568  chars  217500/2108622  ==============
# S, Woud shas, an heer 'osalr, pordene nanp:ean wem fore
#
#
# AT	I boe oou aot 	f ifode whesec wetiel gan
# ========== Iteration  88  Loss:  62.4443243693  chars  220000/2108622  ==============
# Y sascet
#
# O[LEO	Tut wiNhing cit lasd lhag iomtoug orller Aivb,
# 	Sas thos mort aus ile heaverir sasyi
# ========== Iteration  89  Loss:  62.3161297662  chars  222500/2108622  ==============
# S
#
# LDT:!	sE yeSec I thet thex.m amt ictitrrt y yauras tor als, andob dians Woutf' sy wit ikher hetsoe
# ========== Iteration  90  Loss:  62.2171970195  chars  225000/2108622  ==============
# pfitte yiv, fob cocirlepeylrej
# 	Jnin, Bu, mor ang, pas seey, ardilane dirr ond; wasd
# 	Tot sa ninw
#
# WT
# ========== Iteration  91  Loss:  61.9264032955  chars  227500/2108622  ==============
# Y&;
#  LOS
# vNI L?
# 	Nathe domd ly yonreamar'gn!lg ig afliv
# 	th theutheed
#
# LE)NYth n whusime myoalgyt ar
# ========== Iteration  92  Loss:  61.6605802233  chars  230000/2108622  ==============
# gt af woathintor to mo nyop yo, cflafe bate houky on thent tat waid tondors fhn illdxeake he, anve do
# ========== Iteration  93  Loss:  61.7272534703  chars  232500/2108622  ==============
# b;l's nin?sMd
#
#
# 	Ied I
#
# OLAU	Lam Hoon,
# 	I nisd taceemt ay thent an? forad pat, Pr;deUve sfrinsyoce yo
# ========== Iteration  94  Loss:  61.5646009356  chars  235000/2108622  ==============
# Gheue
# 	haus g whakl that se.	lit se shiltoac enet sy !hor me, wheife bt?b sy scorrotd Iiy ou be !eret
# ========== Iteration  95  Loss:  61.5085066258  chars  237500/2108622  ==============
# .
# CSTASDI AI
#
# 	Ao sh'nsg diod thaon bt ving iE en;	Iill lrretd re Iher; wh pud o am
# 	Hor warvri: eing
# ========== Iteration  96  Loss:  61.5316298375  chars  240000/2108622  ==============
# !KW'Ld my Oair monklpby be heetid ann!omdcomd,
# 	Aon, shoue, ooml, goNd	rod bire yo ths ans
#
# 	[ut re o
# ========== Iteration  97  Loss:  61.6363143891  chars  242500/2108622  ==============
# ve 	dt y ; a lhathen toreyes saenbes iind fod Noo: tf il, so dr anasnideg fhlelon the mrpn?lcis tory
# ========== Iteration  98  Loss:  61.5701140539  chars  245000/2108622  ==============
# UXrrinl wgsordond hotteoad;:
# 	I tt yt-l hcih, tira, ilthochet sone tmashiy wites manles tou baI be at
# ========== Iteration  99  Loss:  61.4232180709  chars  247500/2108622  ==============
# !	Wyd I
# 	Dhethas hav, erh tolo sot  ootsalkefd, rfalcor,'e me yik if mab?
# 	Iot thy ton lomer
#
# R'SAIL
# ========== Iteration  100  Loss:  61.5007388372  chars  250000/2108622  ==============
# MEatf minn,s
#
# TELVIEpDH
# 	I
# 	Io 	thabs yre de sdver?
#
# 	IA	Iod
# 	we I yome he me.
#
# C[VLlir Ios, lf.oms,
# ========== Iteration  101  Loss:  61.4635039112  chars  252500/2108622  ==============
# s| eneri.
#
# RAOLRESIVAADA
# SO]BEE
# 	NHeny aml Itut If
# 	We ante  ingniand youres', gegtd thif au fhe hadb
# ========== Iteration  102  Loss:  61.5499639846  chars  255000/2108622  ==============
# buw?
# 	AomewUs: Tee's i
# f-eind the netnslod hovetersuly in.
# TyR'Ird follr,, and bas hoo tis yo oleim,
# ========== Iteration  103  Loss:  61.6021252694  chars  257500/2108622  ==============
# Tak
# 	he kor ho fam
# 	nimou,; inclr,b
# 	u!owte cher hhun goutheu tor tot wore,, mlse me; yils tid boms w
# ========== Iteration  104  Loss:  61.5760114804  chars  260000/2108622  ==============
# ux nolgt] aothe than du ois arr, al, an ancer arsir sre, awipse nimilhyy roag wonetwexherouddos mot a
# ========== Iteration  105  Loss:  62.0851391483  chars  262500/2108622  ==============
# HWcu, POasy fan mouerluolt,.
# 	Te clm thalasl drethid, mass thet do ils I rafsrinedhhrd asd forlro, yo
# ========== Iteration  106  Loss:  62.0221080183  chars  265000/2108622  ==============
# RKan th nouvet'ok xepandwer woade: bf hort ol leclherd Ten. fond tl aag ar ony the gavis heee'nunt sr
# ========== Iteration  107  Loss:  61.8388143504  chars  267500/2108622  ==============
# ,,	al.
# 	Oles'retratane theveth in teondr 'here werhontde, Te movele an afy fomho bbo milart meeis wor
# ========== Iteration  108  Loss:  61.844531203  chars  270000/2108622  ==============
# r
# 	Ihe er hledal?
# 	buts Ile setind
# Tinr	wh tlonpn wos bono tame shy t Iaid thiut usydeln foNafiv mer
# ========== Iteration  109  Loss:  61.7833725433  chars  272500/2108622  ==============
# thid womk; baf mpwrisirthe de Cit fheadbh auheu	she sir vite steues qr ghathe rhidkorn fe steele meer
# ========== Iteration  110  Loss:  61.6361380844  chars  275000/2108622  ==============
# Snin tfetid slimade, syas,de me soupdin tirlor
# 	Uurwiunrey sare s ator whin
# mToovs pouvom cher.
#
#
# SS
# ========== Iteration  111  Loss:  61.8023405249  chars  277500/2108622  ==============
# U
# WiEE
# ABDODvUnN
#
# UYLINLS
# 	Iet Ir fave tefld oul, vome:
# 	Wlor thaon, :thive,
# 	fave nesw hatk bsd beer
# ========== Iteration  112  Loss:  61.7932546703  chars  280000/2108622  ==============
# b kla herniler, bave oug acgurts harel ,a! murr; ne
# 	Perou poe terdqiedeorsher, riml tallnda'k, wom t
# ========== Iteration  113  Loss:  61.7695345986  chars  282500/2108622  ==============
# Wiveur 'a! me cati gheep hut nast or arezit 	ye, sy aag doom wfeal; and tas tobe beleris sa hsare.
#
# A
# ========== Iteration  114  Loss:  61.7273235893  chars  285000/2108622  ==============
# UOKANI Hhl hhos TsS
# RnOHUPUAMIS	Dou I Iowdes hfor,
#
# AADNRO	Tuoca.
# 	Aeth we. , tos yeus
#
# sHI
# 	Th myamt
# ========== Iteration  115  Loss:  61.5471343887  chars  287500/2108622  ==============
# JLAAUNOS	So laccfisnto fos
# 	Mhom vemert 'r vorekiad uhathe.
#
# FA[NNdvevr
# 	Whuthe oty nof tatn bfom!
# 	N
# ========== Iteration  116  Loss:  61.5762326037  chars  290000/2108622  ==============
# Nyrec,:
#
# 	Wo, Kit tot blbond hor they gutheu be be dore iu- wihe sesse thithiw seane site
#
# 	IUCoAs SK
# ========== Iteration  117  Loss:  61.5268466271  chars  292500/2108622  ==============
# bSn th lins seu ot
# 	O bou drfwitaI ghers ond thilt he thel bithece? mounlere s, on eurt youl sand tha
# ========== Iteration  118  Loss:  61.444595589  chars  295000/2108622  ==============
# PIgy ilnt and mawe am; he ted; oi; sor. IurJ I tal ineon, ane thonnso ou coue hitt Iot a eanes Fhe y
# ========== Iteration  119  Loss:  61.4659470236  chars  297500/2108622  ==============
# -:anfk hir, hans one tho d.
# RCANS	Filthitt ceite son un thed nnon sfit arthil  Riky th nee tikatilrre
# ========== Iteration  120  Loss:  61.3265266202  chars  300000/2108622  ==============
# hir?
#
# MUAYUNcBDxCUFP Per he suthe trod :e bir.
#
# RCOEUHEFFan Ueen s wimr,rir th head higert oe ye maon
# ========== Iteration  121  Loss:  61.3931927752  chars  302500/2108622  ==============
# ove bees coy
# Ike vor hild ary kas s mo an' wee s chy wald erpind vefot med! outhekt
# 	Ne in mete lhe t
# ========== Iteration  122  Loss:  61.2612394626  chars  305000/2108622  ==============
# d tu thon 	oi nonste.e
# 	Ira aicirst, Ing nauus, kouaweckiatiy Ycont up srvy dor wofe gwtr mnim qor me
# ========== Iteration  123  Loss:  61.2166258256  chars  307500/2108622  ==============
# 'I deassshon'l, I yoas: Hom]I	Ir fhaldrepthe hiv'rSsy fo eg- ant, cou bhesthersen?
# 	Sngid ist yor bat
# ========== Iteration  124  Loss:  60.9704706757  chars  310000/2108622  ==============
# bimy: ceut ir bitlensed hir ve?
# 	A and, hid son : hos: t, ene the, he b, mond, und ar th anilrel fI
#
#
# ========== Iteration  125  Loss:  60.954860292  chars  312500/2108622  ==============
# : hel
# 	Reme	thy s, saw, Iyuther sor,
#
# RERRYUPPUSYUE I FU
# 	Cat I chare)s, mulnge un nowt?o
# 	Irace th h
# ========== Iteration  126  Loss:  60.8504225389  chars  315000/2108622  ==============
# qnyein sor. Ronoinle Bu,
# 	Wqfela, what iipcin inghero. d wislef yesacg hken one so thesr thenisl hon
# ========== Iteration  127  Loss:  60.7603212285  chars  317500/2108622  ==============
# ; jiqmt ae pwar ih tothet
# 	che moth ceartee de.vlrerg lcom, on the cou mhs in sind gh bp anevs
#
#
# YRD
# ========== Iteration  128  Loss:  60.7420465516  chars  320000/2108622  ==============
# tO pime so hr.aL I] Iu haw H.
#
# IUS LOPWYOHESFHAPA	An ah hol'ds yeshined,e	plilke Womkot piveuom, yore
# ========== Iteration  129  Loss:  60.6103112519  chars  322500/2108622  ==============
# (Edi; hyow awtald ys me, misy thau she lhan.p
# AO, Ih MriSd
# DARGSS]OUO	I sow,
#
#
# 	Whre
# 'T?
# 	the'
#
#
# APSE
# ========== Iteration  130  Loss:  60.525947468  chars  325000/2108622  ==============
# &phe seuns aniny y wais ar Eshenseek ed, wosr.
# RACUIo nn the cyot sle Hasd ne ufthitoth an teud welk
# ========== Iteration  131  Loss:  60.5222518203  chars  327500/2108622  ==============
# YWOOSLWFI Pake n fhob iat mi	bn widdr Ihis!
#
# JAPPSRAALEM
#
# 	ANWeat he my rfase, gadle yti.tat
# nTdCYON
# ========== Iteration  132  Loss:  60.7298911586  chars  330000/2108622  ==============
# ;'ly srot s; Yond Awe Pould
#
# PSmSN	Hy my II sot hor wem  oonsts mi, add maf:
#
# S
# RT
# SHASPEIOAMOE	I dou
# ========== Iteration  133  Loss:  60.7407532188  chars  332500/2108622  ==============
# F-L	yort lo he celn's eancasplom.
#
# URRSSE	Risr wyamlryhels. H
# TARRM	Eu
# cittt
# se igow,
# KAh rid fOof a
# ========== Iteration  134  Loss:  60.5427686579  chars  335000/2108622  ==============
# lale  of tolnct thee deteond shul yvis in dee: bony fhavd him mhou kt ou vome,
#
# APTCNUNENO YSID	Bor m
# ========== Iteration  135  Loss:  60.4256539236  chars  337500/2108622  ==============
# the inds.
#
# FF,I Hhe meth'f soos thed hime  ore?
# 	[ouey wyeans ;woass, meteend thime 	I gid wu, 	a sos
# ========== Iteration  136  Loss:  60.3198735266  chars  340000/2108622  ==============
# slherd;
# 	G horpumesong
#
# 	Anim.
# 	Ainhe lirs turid frthin caglcisy sree:
# 	Ad'pod dim,,?
#
#
# DNMSEEUNL APR
# ========== Iteration  137  Loss:  60.0943416216  chars  342500/2108622  ==============
# !NcTCENS	I themat thela weeskererisns the he winhe	as ly in fould, on, int mof forgt ey ho' breawo si
# ========== Iteration  138  Loss:  60.1925742733  chars  345000/2108622  ==============
# yothe s.
# I(renO Ie mo	fhe thaan sxnthe.
#
# CRCSIYHLPSSCLO
# OSOUI
# DATO PR	IA OApas Iheg, and tod tsas on
# ========== Iteration  139  Loss:  60.1542426687  chars  347500/2108622  ==============
# [er.,
# 	Tyameutur theild le' frrear.
#
# UARAUIM Fr, IE I wha stoid gufels reme yon, guaf lseith, bethur
# ========== Iteration  140  Loss:  60.0649604822  chars  350000/2108622  ==============
# EPUA[SPSANR	In tu he acer, Wyuld hato hef mler.
# 	[drerr!?
# 	Epty mYimnrorez of io mesf bomas:
# 	Whou. h
# ========== Iteration  141  Loss:  60.9692842596  chars  352500/2108622  ==============
# ole,
# 	Tfrein:	Wom'd m
#
# IDNP[An a	we red, haphe piy fith, Iy waer mum: 	cethee,,he: cpour.
# 	Thar Iy as
# ========== Iteration  142  Loss:  60.9928465195  chars  355000/2108622  ==============
# l? 'osbg ftide ylathss found tind Ibas so he lha d ciras that ther.
# ABPIS	Ln anrat aorits
#
# 	Tores
#
#
# C
# ========== Iteration  143  Loss:  61.0989356319  chars  357500/2108622  ==============
# ''ses, yhicodde.
# 	Thlimt tirt,
#
# DANNUSUP	What mouf manan
#
#
# OEDLUENO	d thand whir. DCtARESALUI lE yIan
# ========== Iteration  144  Loss:  61.372069032  chars  360000/2108622  ==============
# M(t motos isnle
# 	Wh mel, broce areual wout ss yime oedt't be cows, me me Bo)s sher aether
# 	here mouso
# ========== Iteration  145  Loss:  61.6210970592  chars  362500/2108622  ==============
# H	beuet ynenl both;
# 	Oid miltol !y she mo:.
#
#
# AILPUFPFS	I Irinsan ]h wer tlam tule-klreds ieke sis.
#
#
# ========== Iteration  146  Loss:  61.6067556615  chars  365000/2108622  ==============
# Kptp uerting.
# HAN] SiG mrule he sarid wicled mert orns, I
# 	fe thar hes man
#
#
# BODEOENU] U
# 	I y ointu t
# ========== Iteration  147  Loss:  61.6093387016  chars  367500/2108622  ==============
# fbreds wasnaveraserass hein wonchep ancpoulk Chel piblendtal gweyuut feu ind ginn
# lard'mim]
#
#
#
# I
# 	Mou
# ========== Iteration  148  Loss:  61.4733085946  chars  370000/2108622  ==============
#  mariocond thercd ay phe peemorbtder aathangee hot honc os, Ile y fo d.
#
#
# ILAUUSEINE	Ux,	thot derapd
# ========== Iteration  149  Loss:  61.2799448582  chars  372500/2108622  ==============
# den. pofs, boit youl
#
#
# EUSrIEBNN	S lore,
#
# IyHLPICENUU
# 	Hoy theun m vat bak.
#
# SUCMNMSCOIOClORNTHI Thin
# ========== Iteration  150  Loss:  61.4323457917  chars  375000/2108622  ==============
# me
# 	Boin' hat
# 	A ce and f um chabe! toit ie!shim, sibs onw ind maron
# 	AreL bol noh damks.
#
# 	T my heer
# ========== Iteration  151  Loss:  61.270481746  chars  377500/2108622  ==============
# |vet ath algteels oud re con,	thind, she wit donp an, a ir ook bud	me indtheconglsssin prlad tet I ph
# ========== Iteration  152  Loss:  61.3548274435  chars  380000/2108622  ==============
# Jxcham both beet mlcidu	'w?boB ko thil timint yhavof, thed soug ?ond we  nes
# d haning, wilr
# 	outand
#
# ========== Iteration  153  Loss:  61.3774179204  chars  382500/2108622  ==============
# ilgep?m
# dAH;AMOE EES	Oresm sfeath ce ttitkechau seuthast and aar ose solst, bithit shev thime wef, wo
# ========== Iteration  154  Loss:  61.2568066249  chars  385000/2108622  ==============
# &px ngt yharer she heove-	Ternr aes arty Iu honitr andeele t me-tard at se ey?,
#
# DIAUAO	A th as tover
# ========== Iteration  155  Loss:  61.1843159806  chars  387500/2108622  ==============
# mas hich tan to:!'D
# 	Avp, at vuthenris ninf
# 	I naciw' tind mot bud'y ue woutheomis f thor wares namyu
# ========== Iteration  156  Loss:  61.2439485767  chars  390000/2108622  ==============
# ashy wig mirge?
#
# ALILI	S alsn he thor minfeu madk; rorse beut kfkad and gor, hace sfitlt, mim; werin,
# ========== Iteration  157  Loss:  61.2780977903  chars  392500/2108622  ==============
# Hco gy and forat, cherive lold osendu h, of rathein weam hers yot xo noithy lagtour fektl'd.
#
# MLCNEMM
# ========== Iteration  158  Loss:  61.2163573922  chars  395000/2108622  ==============
# Ro[G'', oo toryey angesget don so seotbdhysum fat yithe mir bourose, yound if tond blond mor' met ret
# ========== Iteration  159  Loss:  61.1551815592  chars  397500/2108622  ==============
# lvifiss.	Tul caslatt yo mind ar yhat pit tod weld eote d yiv  is anny. Ihe hee mod geesaf mo co fis h
# ========== Iteration  160  Loss:  61.0939475429  chars  400000/2108622  ==============
# AYAJLEPELN
# 	He lo log tnwa sies,t woth, berrady, geor thany not; ouct Rhay y at an'lp,.
# 	phervatt men
# ========== Iteration  161  Loss:  61.0240607086  chars  402500/2108622  ==============
# tun;.
#
# INETMHUI aln and dou tired	fe!; nene 'r he ko! gcees?
# 	Puamtt ps laf mo bo siree.
#
# DALIESLAxI
# ========== Iteration  162  Loss:  60.8559541611  chars  405000/2108622  ==============
# y iurd sheed ind sasinetuer
#
# AYOHLII Mhathel, ho ngat ald seli'd yI the nowlr sobe merevewt ere youd
# ========== Iteration  163  Loss:  60.7093895165  chars  407500/2108622  ==============
# , Chathe thith I thar ilidre sian
# 	War, So'v sate t hele, imife arrnbredo
#
#
# INHNELANUEO	Thav sinve li
# ========== Iteration  164  Loss:  60.7513884875  chars  410000/2108622  ==============
# QCaldon-r-RC	yor 	neterd
# 	wouy boustour Iy fulerktble, an,
# 	Inlts an  I us aidl, did Sanw he om
# 	A ci
# ========== Iteration  165  Loss:  60.9117952975  chars  412500/2108622  ==============
# ber, brtd aif be cf intt nessend ay :or, Pintyde lude vigards Yey	se he be tote Iualt chaveng,rQ; mor
# ========== Iteration  166  Loss:  60.9459651231  chars  415000/2108622  ==============
# .?
# OCUNUI H ney inloms teouset Eew oo''s sare yale a da fafis thoy be't'd Ie ne: ALikO heuno A lruncg
# ========== Iteration  167  Loss:  60.924120433  chars  417500/2108622  ==============
# reyer.
#
# 	[UI, EANTOHMSN	S whe ne: seesne satecice oot, no noussde s at?
#
#
# 	Core Yacoufed 'me sof paLg
# ========== Iteration  168  Loss:  60.912792117  chars  420000/2108622  ==============
# O(lzt'r, boeg
# CACOErs Thiw ' wott ind wose, mo shavn tho sacj toc visls dkef keme arcishes
# 	Whigs ame
# ========== Iteration  169  Loss:  60.689159993  chars  422500/2108622  ==============
# RKEAMALSAMYOASO
# 	AnOxYELHIU	nhl vees ansnot; ar pohe the wother non t ar orsle tei kfin h-en; af mind
# ========== Iteration  170  Loss:  60.7213837557  chars  425000/2108622  ==============
# TIy ou hitl wot at foas iy tourqnis
# 	Tin on me ould tha niryres hale!
# 	Terathe
#
# 	Gave poukd and bweu'
# ========== Iteration  171  Loss:  60.6621173193  chars  427500/2108622  ==============
# beou ;e;-
# 	fhotar heily;
# 	Thawy nliss yavacs y tot coreGy,e thingase toits lout ur
# 	Thil srsyto: iw o
# ========== Iteration  172  Loss:  60.4117101307  chars  430000/2108622  ==============
# Mso weocgon-'bgs.
# 	Auy tous tha thar thanlyome,
# 	Yoly as Andt rithces
#
# ]ALCETEII	Pos in, mr polaggiin
# ========== Iteration  173  Loss:  60.4522929392  chars  432500/2108622  ==============
# JDwthe e the tand.
# 	Toos
# 	le 'has?	Sade an'e tor femtimgj
# 	I :o
# 	I minou, toc reer,
# 	What,  ilas e: b
# ========== Iteration  174  Loss:  60.5266739651  chars  435000/2108622  ==============
# ES	[oo
# 	ml me iit mthexerclorgsmritharrtery cr afiud dirn tu set qantaf witu
# 	The heom' ke kertsek h
# ========== Iteration  175  Loss:  60.4239899982  chars  437500/2108622  ==============
# ow ,es tey ourd,
# 	An brgcas
# 	Yoler horanj- Thitgesti tood I
# 	woeg mhim: lovef] colis gakr lof ro't fo
# ========== Iteration  176  Loss:  60.4034815987  chars  440000/2108622  ==============
# p-le gom merd,'drsessenhit prive hane tom
# 	Thes, Oever.
#
# C[RIEE	PGiT of Oty bou pytett he ery houre n
# ========== Iteration  177  Loss:  60.3725943829  chars  442500/2108622  ==============
# he he ,fere Thou he ny.	Wowalr ghbims fuud mofhou is ut cerentn okd ece bins anassous
# 	They cefgmill'
# ========== Iteration  178  Loss:  60.288010687  chars  445000/2108622  ==============
# hgul parl;
# 	Thou thi mithy sl gat  sathe thes nf yacwums yhar, sey fo los uongbhe le'f we lot lt ipnt
# ========== Iteration  179  Loss:  60.4276634041  chars  447500/2108622  ==============
# Hon? Tlcayeduvereinleror- fh ditl nronlleruses r all	sreren: houder
# 	Torjjeom inosp, arcis nedthenoag
# ========== Iteration  180  Loss:  60.4880868236  chars  450000/2108622  ==============
# t, mo pmas t.
# 	[ht wiet 'q ta ourU]
# 	Oad hill: ang
# 	IUdn't cale bes haun doupsill or-.
# 	[desagu fot r
# ========== Iteration  181  Loss:  60.4287141063  chars  452500/2108622  ==============
# ha. Ant sabalcengly eoth dult mulesg kour
#
# C.PEUOAUt SI I an: NTnSI O Than	n thine'Y,
#
#
# II	Fheits war
# ========== Iteration  182  Loss:  60.3173397543  chars  455000/2108622  ==============
# Agl.
#
# CINEGUE	Lou oansout meet; weyof got e pam Tae; hinr
# 	There hwe ofawt vopot mome: foy mo bot Yad
# ========== Iteration  183  Loss:  60.3049527426  chars  457500/2108622  ==============
# j) mamd ouge ftoli-hte belt at boreis al folilld
# 	The hele.
#
# NCUHEEAOI?	If I cpco pak wisbrye fou d o
# ========== Iteration  184  Loss:  60.2504250292  chars  460000/2108622  ==============
#  mohi!
# 	Mf fyouth.  yrad heltri's meons siin ous dot th tatoul.
#
# PU[PUNE	Mn auk sourid furwewPthes ha
# ========== Iteration  185  Loss:  60.3306219553  chars  462500/2108622  ==============
# (HZWuQ e beldict micans sok thyine,
# 	nake kogte rith w yard sraclnt rceperiligh sar. IOrd B at in sea
# ========== Iteration  186  Loss:  60.4348737583  chars  465000/2108622  ==============
# jry ree ind ne, , thescourp;
# 	Aont' yerte oroththang ire, ho thend.
# 	[hed btbamich, hlarenl.
#
# IEMwEE
# ========== Iteration  187  Loss:  60.3338979858  chars  467500/2108622  ==============
# yyedceil? I dor de yaatl.
#
# ANIO	Lam thic , the fibt llogekt te 'redes;--lfthand.
#
# RALEIES	Ir aoe bist
# ========== Iteration  188  Loss:  60.3033355758  chars  470000/2108622  ==============
# ;
# PRLUSUUS	So hey the wobe er theef
# 	Bit, :y my mos
# 	brith lith thecinwg an'ng yhee arcu, yis byess
#
#
# ========== Iteration  189  Loss:  60.092934123  chars  472500/2108622  ==============
#  The t.
#
# LASENIUS
# 	Ghe Iy ufs as sy mhin.
# 	IR	Youranitc meesces fom ant s man-y oua g.
# 	Swerunsrirtee
# ========== Iteration  190  Loss:  60.1180953063  chars  475000/2108622  ==============
# luth ang amlas
#
# THYRLUEEE]PTMINRNe thed th rof
# 	LG bele nand y anow Ofaded worec ou ns ;ian pasbye th
# ========== Iteration  191  Loss:  60.273763429  chars  477500/2108622  ==============
# d unler	cuth Brofs hor steon!	Bin'deld,, outwurle yhom tawer poiy it houlr
# 	Benard hon! eor seun:t
# 	Y
# ========== Iteration  192  Loss:  60.1760010231  chars  480000/2108622  ==============
# ked agath? The co ame yfoond,
# 	Bhe m merde: woad teashen
# 	an at theavivs alld ? wyashe bosconess suea
# ========== Iteration  193  Loss:  60.2607360222  chars  482500/2108622  ==============
# pod afs Hae, ant enatr,
# 	Bo, wesilet mryan!	moun moct akoclN
#
#
# UMRILUI MTiGn his Hilhinid wlonte thy
# ========== Iteration  194  Loss:  60.3067410764  chars  485000/2108622  ==============
# Kve.
#
#
# AMEx] I win CRud Icing They I
# 	Atlebb hes yalh. bore-kh dg,ike,
# 	Whax nots
# 	path thet hit mlrs
# ========== Iteration  195  Loss:  60.5175754341  chars  487500/2108622  ==============
# OChers'	nas? Woeet, w ue that arounn ;ot, s asloud
# 	Ant tior sor boutrlve.,
# 	Sot oidd;vim
# 	Womus,
#
# 	F
# ========== Iteration  196  Loss:  60.4632657972  chars  490000/2108622  ==============
# nr: wersd Jout aany ir the thor, fey ofo fty e and teed
# 	Tor toor:	kr uer yhed wor thee cithamnur nfo
# ========== Iteration  197  Loss:  60.3768451201  chars  492500/2108622  ==============
# ing oods
# 	Bo omo slyowre,
# 	Daris beigore he melgepangse	ding yullow and thou
# 	shon, noannher,
#
# MUTTEI
# ========== Iteration  198  Loss:  60.2636546973  chars  495000/2108622  ==============
# w wo sicg ind ahe; ban thit
# 	Funme beye and
# 	To wsai
#
#
# HTHIKUI	gint an he thou-Pean
# 	Hou	gett, our
#
#
#
# ========== Iteration  199  Loss:  60.1315436482  chars  497500/2108622  ==============
# qyoj.
# 	Wyill, bide:s ongeninc, bot lott gour yeo chat ypinrevar.
# 	AYcanthermrlracere cho hessind
# 	[al
# ========== Iteration  200  Loss:  60.1039100579  chars  500000/2108622  ==============
# Yarfusfawin: sus ty lofas,
# 	 a wu mere wocatesw.
# 	Yndean shit  hou sutn shareges?
#
# CRo[NCHAS
# 	H! AMOT
# ========== Iteration  201  Loss:  60.1693058952  chars  502500/2108622  ==============
# , y ancetinl;
#
#
# CM[IELOCAkRP	PoL LONUUS
# 	Bfeca le raleslafod:
#
# 	Where, Br I horcs in tichis  'sy bo m
# ========== Iteration  202  Loss:  60.1326291789  chars  505000/2108622  ==============
# &Ses.
#
#
# 	[YSNFEUNUA	ne sip beort xosd coime,.
#
#
# AAIO	Y col : couy'th, minll vos turd too hat uleir,,
#
# ========== Iteration  203  Loss:  59.8621084074  chars  507500/2108622  ==============
# gpath Ge tarc !, wee I o I ;op couces, irgounan :iklis.
# 	SS I ald hind
# 	The ghot
# 	Ih wy olpoyit in ac
# ========== Iteration  204  Loss:  59.6584179178  chars  510000/2108622  ==============
# 	qh thind bu lobe tnperine,,
#
# INSOEUPEARIEU	Ne tham thof,
# 	Hels erim sarerinrichet, int touchang, bed
# ========== Iteration  205  Loss:  59.4710392758  chars  512500/2108622  ==============
# llandir.
# 	Bumlgmehs wiy ouss
# 	Aysthid st iow sor,
# 	Bere han fim the pres, ied balc, A'd Whis seendcam
# ========== Iteration  206  Loss:  59.6137309126  chars  515000/2108622  ==============
#  met omiur, sare,
# 	Mo.]
# 	I s eo thangpk
# 	Tonls-oindeen I
# 	Yime thanlfto yhe fheck
# 	I tapes  ier-
# 	Tha
# ========== Iteration  207  Loss:  60.0456188906  chars  517500/2108622  ==============
# [O'un
# 	Af I seed sor ala'k ouve toe
# 	O berbRonttw thalhe, mine gourd apithu shese voslerher Gure m: d
# ========== Iteration  208  Loss:  59.8702797197  chars  520000/2108622  ==============
# DKDR	Imer
# 	I i tisgy, holce,
# 	Mert: Uhead old ABter pale thamefs wirhety-
# 	Than yave 	Htal, Iiane me
# ========== Iteration  209  Loss:  59.8842084163  chars  522500/2108622  ==============
# cYwa; sy pnUbe sisd I ou de penos, bedt'nis mus hing
# 	Chefrlrale, ae he mousy -eine
# 	Aami yed
# 	WoEd t
# ========== Iteration  210  Loss:  59.8594332883  chars  525000/2108622  ==============
# nen	fhes fontelkprdrrhos er il at pagsy bos th ls .Fin meesc paderon tham thers.
#
# SOS	Ot blo cossi ha
# ========== Iteration  211  Loss:  60.0405625077  chars  527500/2108622  ==============
# xt hiss nryhialo sorld-
# 	Ke Iir tafthans ongeusd br le alle hiron yrarrenoas,
# 	ISgore; I t he ingewas
# ========== Iteration  212  Loss:  60.1720894885  chars  530000/2108622  ==============
# dKme!
#
# 	Che w asther sou hrasd on, tars
# lFol theld gulisl.
#
# DRIARTE	Go upitho thou diin be one es! wa
# ========== Iteration  213  Loss:  60.2129171902  chars  532500/2108622  ==============
# The s a tee, wameedeis hak keny, slotpustrlilife ard m we: Dyey thod Gar orleud aiprar.
# 	Felay oo t r
# ========== Iteration  214  Loss:  60.0779430393  chars  535000/2108622  ==============
# loy: whyle guis miwh. nun ios kr bolitin] th lithasg'rrletts ord gens!
# 	Frtet yout th thil-, Iremas,
# ========== Iteration  215  Loss:  60.0591153439  chars  537500/2108622  ==============
# NI'l 	ise enans len ery Inle anait
# 	Mr ieid co yor, on solthede]
#
#
# IANAGSR	I pE A oy fhomad pin, thet
# ========== Iteration  216  Loss:  60.2422495234  chars  540000/2108622  ==============
# kBpxgseeveun.
#
# CBN|NSEOD ToutA	Go.
#
# DEFMEA HaD BERASEVe d tI the domlemid ,
# 	Mhe Core goun, thar lon
# ========== Iteration  217  Loss:  60.0678295608  chars  542500/2108622  ==============
# bn thy  ore hine sidnsbry be tow ore, thi s and lobenstiry melf.
#
# ANCEIDYOMROARdEI	Andd cofther beasi
# ========== Iteration  218  Loss:  59.7899629802  chars  545000/2108622  ==============
# [pulertd,
# 	He thad
# 	Slicin wpod billedesg. hirith; Warghe merthan  ayo thordt muthet ald ast sofeo he
# ========== Iteration  219  Loss:  59.6896596756  chars  547500/2108622  ==============
# Awd dyowl is torise siky eo hanl thew cher hath dase malin.
#
# TULANANTHS	D iid whe tecs
# 	Tfmwe
# 	Wib
#
#
#
# ========== Iteration  220  Loss:  59.6496346824  chars  550000/2108622  ==============
# D'NceOuike co. ou hour
#
# IN
# 	TEI	Arender ou werd nfly ut ot mleth rougtesest.
#
# 	Hishrsourpge, norakle:
# ========== Iteration  221  Loss:  59.5480864352  chars  552500/2108622  ==============
# x wshi f; cakthit ched olordrere
#
#
# INBI	S xiniis have th uy thun oam he tone r ts wimutil whey hy bam
# ========== Iteration  222  Loss:  59.5913107418  chars  555000/2108622  ==============
# S hils s setome, yor pote oret: she thelstluvein mencomesy soun tidn.
#
# AYANON	A wharlad
# 	Sirrenle kis
# ========== Iteration  223  Loss:  59.5198564358  chars  557500/2108622  ==============
# WyA win irrte: thor I seithr toss gaEw ]N
# 	Asme the thy t t ly af: mer arl, weim coer: Ihus encelg no
# ========== Iteration  224  Loss:  59.6128930116  chars  560000/2108622  ==============
# ENPDONCRS	Yhe thin ou irsins.
#
# MTE	ARd
# mLOD
# 	Whet elte wamlpacithe, hare hane the,
# 	Ir int pethrrele
# ========== Iteration  225  Loss:  59.4210334482  chars  562500/2108622  ==============
# Zerd imin 'ref iny
# t homn and cath, fored.
#
# ATOS	Se the  tore Haspemneent.
#
# DRRES	Ho thars rnakvins b
# ========== Iteration  226  Loss:  59.440953032  chars  565000/2108622  ==============
# ;h merithovat, aitl iucaeneard mapfeMot were stase wome whcwoat mo theurn;
# 	Areree thy boge npesthue
# ========== Iteration  227  Loss:  59.443893211  chars  567500/2108622  ==============
# xxtlo, se tio punl'kfst remek nom.
#
# ITSED OR	Ghow wowshene fur aogwat sssts it at cod heac!
# 	Weov, Sr
# ========== Iteration  228  Loss:  59.5864890104  chars  570000/2108622  ==============
# unu, our baalsees, tharpalh thans-ot ther wasuk in lo sheus?
# 	Bridelell shand thou, igs in ctod sosno
# ========== Iteration  229  Loss:  59.8248218702  chars  572500/2108622  ==============
# xe?
#
# DAxIZERLHAITHKQOXG I
# 	SAwARRESOENEA	Nore,,t, bot ou pact laod ffelthe borog nin prathire. sad.
#
# ========== Iteration  230  Loss:  59.7921176518  chars  575000/2108622  ==============
# Gy pe wove, crireono, ho bt wher eyom hale lon.
#
# IUE HE	Alln	thet; bpomade soaind me loce npsf yty Sm
# ========== Iteration  231  Loss:  59.7124393542  chars  577500/2108622  ==============
# YAAGrich m So tot an porober, the, the and the r've sur ardek
# 	Dprone ghin e gheus or,
#  fo thoug tor
# ========== Iteration  232  Loss:  59.7400536984  chars  580000/2108622  ==============
# prastobe Be hir dotthe the hout, bed;
# 	OStuno ord?
# 	To ghluss
#
# 	On Drnereeg?
# 	Mhaspor tol y, our,
#
# 	O
# ========== Iteration  233  Loss:  59.6227680767  chars  582500/2108622  ==============
# bxeeghe base w ad heind.
# 	Hham aumed waos
# 	Ant Rr
# I TEEBA	V d if at thek as andere, minlusion on y ao
# ========== Iteration  234  Loss:  59.5473017083  chars  585000/2108622  ==============
# Awhile, thet. Olore tou tad  hend ichavy hou tooud ar the mins, pestr ne coma foui? Rlilitho chit she
# ========== Iteration  235  Loss:  59.4349614918  chars  587500/2108622  ==============
# .
# SON	Whre the
# 	Wtalo , lava bad pamnne mime.
#
# O[T[SLANLNRON	I Roxeud
# 	I mert me vey the, shaveng tha
# ========== Iteration  236  Loss:  59.2706658403  chars  590000/2108622  ==============
# Zqzwe dilbon
# 	B alr sher
# 	Anderr alrsd,-.
# 	jmpild bb'at ard
# 	beannop horses lu kads,
# 	RoYavl cxgishm
# ========== Iteration  237  Loss:  59.0808961442  chars  592500/2108622  ==============
# Kovl, andery?
# 	Bee d?
#
# TESD	Iuln bad thasitf: rarn l mu yorkens tlo: shikesh fore nfare wage prave bi
# ========== Iteration  238  Loss:  59.3921355563  chars  595000/2108622  ==============
# ]
# 	O thave d mtow, asd mmaniint; w ard, yoe how langlee: thyeve, and tha ger ceoy sunllt, white mom i
# ========== Iteration  239  Loss:  59.5948698222  chars  597500/2108622  ==============
# Sd hard, 'oy ftive fate
# 	fli teou, banl:'g, woy, mf, iltce fiml pof moss wea; mo blese sate, pit hitt
# ========== Iteration  240  Loss:  59.4999269622  chars  600000/2108622  ==============
# ZRCMxS HTOE	Onde rsuty an il,
# 	henif wore
# 	hhir fun; Lndith tw, aur lricorond here the qo biw thumes.
# ========== Iteration  241  Loss:  59.4218181149  chars  602500/2108622  ==============
# cerlf--of, the hefer, hrine c, foo harerid :oo' the ankppami;
# 	th see that due geest le-the cat,, tta
# ========== Iteration  242  Loss:  59.3076652333  chars  605000/2108622  ==============
# Lhuir,
# 	Fit ind amd woade bidhean; sithet mbecd.
# 	Tire w meaty end fye,, I thiin it ating.
#
# IBE	Tcua
# ========== Iteration  243  Loss:  59.1141360358  chars  607500/2108622  ==============
# froll?
#
# TNCIMSNAS	Mhig: Incf;ow,.
# 	Inist theu tha  arecith or.	I oor.
#
# CSRIREaS
# DOALD
# 	Aok a bus.
# 	Ah
# ========== Iteration  244  Loss:  59.106832501  chars  610000/2108622  ==============
# Sin, boy'y theyblky bio cedecd theth bed yeer kilgllrye: hocl ir uss mpos tir cion, than Hof wave sfo
# ========== Iteration  245  Loss:  58.8219000429  chars  612500/2108622  ==============
#  He hacg lnfis frouncc?
#
# AIRLIFEd RELI]
# 	Fet and disf wyus myeot yor yaocl aas anss'l ther hinn cy la
# ========== Iteration  246  Loss:  58.8683516205  chars  615000/2108622  ==============
# &xan!rmrevulu cows tharourler.
#
# OORCAODNI Nrar minese th ar the had wime he, jar fuareasy thad sin he
# ========== Iteration  247  Loss:  58.8126158448  chars  617500/2108622  ==============
# PNHEDMITMGRoEE	[hat thend qothing
# 	Ot tes anlas?
#
# CELTOEV	Do ase wit caegens, oud goresicy eon, sor g
# ========== Iteration  248  Loss:  58.62723838  chars  620000/2108622  ==============
# VeOqmuspsgand Dorrtoud path onsb,,
# 	I routhige taphes
# 	Thozryiun oy fore toir,  uath your,
# 	IE dall p
# ========== Iteration  249  Loss:  58.5166877629  chars  622500/2108622  ==============
# ALAUI L A [EG N Iou ant n win h, ehe siat youm in t ociss fe t or bades'dn somarlssinghert the in.
#
# I
# ========== Iteration  250  Loss:  58.3648187575  chars  625000/2108622  ==============
# kar gouss gean mit bat ot of and ther,?
# 	Mars shamet souts, gRrerweru, hin that; walith or the mlf sa
# ========== Iteration  251  Loss:  58.2212609875  chars  627500/2108622  ==============
# becs.
#
# 	Bik mrishy ind fle, sous oun, l bt tay: cpet metid bergherk;
# 	Think that Wherow,;
#
# HRCIRIND	[
# ========== Iteration  252  Loss:  58.3967794347  chars  630000/2108622  ==============
# r, dererot tou hurse'th sinkend wareece moundsetu, nome fof,
# 	And wancensarngse
# 	Wases the ce hon sli
# ========== Iteration  253  Loss:  58.5541676529  chars  632500/2108622  ==============
# UEN	Aud and noukaer tor e? wore,
# 	Iu thim paanon! Whet to thone phiin, sww ab touth Fo heacg. fo;
# 	Th
# ========== Iteration  254  Loss:  58.6479216371  chars  635000/2108622  ==============
# RHOE'	T anthe mirhid bu ind anthe tham nibe fho.
#
# 	Migin toon thoresnn	to prany maof.	eik.
# 	Whe ffa d
# ========== Iteration  255  Loss:  58.58809675  chars  637500/2108622  ==============
# , Forlegeser andtLaf theanceo.
#
# 	Haveesd
# 	Horloft; ts sat, nor
# ...
# ========== Iteration  437  Loss:  56.3702654339  chars  1092500/2108622  ==============
# ?
#
# RUTEE	WEipled faall wo drans,
# 	Indelgistyousd,
# 	Wo ion s bes Cave bin coaks sagthelone I thind?
#
# T
# ========== Iteration  438  Loss:  56.3516752928  chars  1095000/2108622  ==============
# beart naR Leas sfith I thes no hongons abn gad mesmeret;
# 	Aall; I iy mere ed my us is thim
# d asish:
# ========== Iteration  439  Loss:  56.6452854249  chars  1097500/2108622  ==============
# Touln mare minoulthe gow
#
# BHvEE	, maves woul, on sicf per	thyidn.
# 	[ere noust beoo bunee werek me fro
# ========== Iteration  440  Loss:  56.6410618814  chars  1100000/2108622  ==============
# C'LI	Mhad yauplrith;
# 	B.a ton chathel!
#
# MEYSTAMTE
# 	[ined:
# 	I duthe,
# 	Oud chibke, withac ther.
#
# FEENNE
# ========== Iteration  441  Loss:  56.7008346646  chars  1102500/2108622  ==============
# y, pyo gik,
# 	Heaggime theicr
# 	The musthe s
# 	and oas cuthare thiep hnang, wite ild wyorss
# 	Whe ryouln
#
# ========== Iteration  442  Loss:  56.5545415624  chars  1105000/2108622  ==============
#
# 	Thast nis feel fhe lamcy
# 	hos toot an per;
# 	I why f ar he kourllentior thid ard an A chand?nat, 	fs
# ========== Iteration  443  Loss:  56.7056039578  chars  1107500/2108622  ==============
# !	Olcurly ake Bither a this'der; op wave in thele dimed ar cet hild.
#
# DEREI I thou loves.
# FHoK I VANU
# ========== Iteration  444  Loss:  56.8156188963  chars  1110000/2108622  ==============
# VwAg, IURNSAL
# 	WTou wee  asdsingen;
# 	[xaad sar
# 	thent' is or uld cfy
#
#
# MUCERDAR	Wy tharedy; acd:
# 	A;
# ========== Iteration  445  Loss:  56.6860219032  chars  1112500/2108622  ==============
# |?
# 	[Tik giin tary shepI aime, fme rallasw srookesece, puatee; coky tyoug-	by;
# 	Sighing gtele in A ap
# ========== Iteration  446  Loss:  56.6485278729  chars  1115000/2108622  ==============
# qvend outs lome; bet ny or, Iom.
#
# PELEUQUA	Hers torece.
#
# 	[Eo  av,
#  a kd oro meny come,
# 	Bun leime
# ========== Iteration  447  Loss:  56.6595103607  chars  1117500/2108622  ==============
# BVRTATSIR
# 	Anllem gheress ooks mu notle do nonle; Io sho tang.
#
# MUFEqTEIN	Lfand, Pors,
# 	Whouen mile h
# ========== Iteration  448  Loss:  56.6332607698  chars  1120000/2108622  ==============
# , sheer af acamape me hhe tfirsastnunne:
# 	The! no herl the' toy wive thoun: the sees naald blors your
# ========== Iteration  449  Loss:  56.6520866605  chars  1122500/2108622  ==============
# QDoE	[fold oud at Btoond,
# 	Bas shom foury madest maeen
#
# 	[kad shour; ia kels!
#
# IUI IRGUCU	Tmat youll.
# ========== Iteration  450  Loss:  56.7735600186  chars  1125000/2108622  ==============
# ]
# 	Oive the you fob ont Hine sore muoyh'r and d ing ary
# 	n'l mereta mondurl me dithE qurith theurt he
# ========== Iteration  451  Loss:  57.1979688393  chars  1127500/2108622  ==============
# BmUWh thas this, sall, angurs bigsrnvasg!
# 	And! yor holid;
# 	And Fthitd
# 	Eil nod whenn shith dtor you.
# ========== Iteration  452  Loss:  57.2505442127  chars  1130000/2108622  ==============
# &sermesnunt flourous all tous come]
#
# SOLEARO	JiscerdeO herces bedertand at lemas t that  asgor ae whe
# ========== Iteration  453  Loss:  57.2762939993  chars  1132500/2108622  ==============
# Apkerer wand arage.
# 	Mwoot seecle forindond ing ere ind, basa berith womd Irrilet, pipwee tlo pore, M
# ========== Iteration  454  Loss:  57.2518241741  chars  1135000/2108622  ==============
# PUINFRINAN|	I ay whim lace pare o ditis wisher. as arlnow uan as berenas loa cianune thin ba nhy os k
# ========== Iteration  455  Loss:  57.1412647579  chars  1137500/2108622  ==============
# nr theun st ther mild po inour ousths pasetit
# 	foon the waab hips cavess
# 	fants'd.
#
# SI ELCERT-BM	Hxer
# ========== Iteration  456  Loss:  57.0629793016  chars  1140000/2108622  ==============
# OR]
#
#
# SIMYIASTON	I atpolk castbmerden.
#
# RUEEWlE	Ded  Aver CuKr, ATULE	YAmene und Toon hel star
# 	preth
# ========== Iteration  457  Loss:  56.8132276065  chars  1142500/2108622  ==============
# Igroursy urthan iy Pith
# 	Ew we tad. ory Het akatrich.
#
#  HEVSEENDEM	Mhou hirchoncl, haalow.
# BENRANAAT
# ========== Iteration  458  Loss:  56.7866258366  chars  1145000/2108622  ==============
# Sclowoul.
#
# HEMTERURO Th A ATOLANB	Infer ouv leof	agislou thald as ha
# geothe nead tour sas.
# 	Aod wanky
# ========== Iteration  459  Loss:  56.8142458741  chars  1147500/2108622  ==============
# ZG?
#
# CECESCUCUSR	I tor her andethaf uy tho ofs by upsee-aly wof the lels I wilr un lfow buthiou t sof
# ========== Iteration  460  Loss:  56.7005676996  chars  1150000/2108622  ==============
# .
# MONAN	AsL
# 	As'mengete, it beave the , or in'overamcn-
#
# CEEUEDV
# 	Mirf
# wtar' gideedr the niy tia!y, i
# ========== Iteration  461  Loss:  56.503900675  chars  1152500/2108622  ==============
# vaz, sitit
# 	sontier that hirn.
#
#
# TSEENTION	Thil Ror;, Lo with hceatner, er thad his sate heus be wave
# ========== Iteration  462  Loss:  56.5945206469  chars  1155000/2108622  ==============
# !mesbesing rfatJ got wonel, I hith OSd: thowse, qhe lyeen: sor, ald masgevt my heirt nich bay us sath
# ========== Iteration  463  Loss:  56.4945148641  chars  1157500/2108622  ==============
# Q!eRlE	Bet Lerker,	will
# 	fud an tou kin is neicist hole yet n wele pascee, as erer ald ungtelene; in
# ========== Iteration  464  Loss:  56.3187124108  chars  1160000/2108622  ==============
# Fuch rrtreat ond oce, of pim. Sore out th  e qllooftich in thit 	ror int finDe.
#
# 	[andans oot
# 	Co kra
# ========== Iteration  465  Loss:  56.1607013947  chars  1162500/2108622  ==============
# 'd serisbe.
#
# TEEDAIEB	Cith- domeer hen, fall dn ne miked lopin hice kond seon therrengelt? fark berd,
# ========== Iteration  466  Loss:  56.2402429516  chars  1165000/2108622  ==============
# |jB |cloF mine
# 	rols haxn huth inde mn beer!
#
#
# VTRMEREOR	Bovend hall I if mote!
# 	He lash han wris?
#
# D
# ========== Iteration  467  Loss:  56.2623473368  chars  1167500/2108622  ==============
#
# 	Bill houafe? I in yoleonkig, M ofpich ghe softhy whin yeo thil 	lats;ro, I o mach o coug, therepert
# ========== Iteration  468  Loss:  56.2084019661  chars  1170000/2108622  ==============
# opr.
# 	Toulluld ur'cere,
# 	Bondung'nort,
# 	Hoftroth tu masn shim ther ol bing.
#
# ACE OLE ANDREDAN	Ann boo
# ========== Iteration  469  Loss:  56.2407297606  chars  1172500/2108622  ==============
# At
# 	TMany,
# 	Or winst peast wo chy chet. -old a bes, yofo'd Jowhand. sed
# 	Nimce sor
# 	suree thispasr At
# ========== Iteration  470  Loss:  56.0751965286  chars  1175000/2108622  ==============
# [EO	Busnenglofpind 'l ceclive inener,ustall! he sond: wisw,
# 	Bhol wad:
# 	Want kis, thom .
#
# ICO	Tonve h
# ========== Iteration  471  Loss:  55.9994086391  chars  1177500/2108622  ==============
# syoroom.
#
# BUSOGA	Thonms too
# 	Afd ko Bisss of cool gore;
# 	Who hid nhis o be the leal
# 	wt ther hom thy
# ========== Iteration  472  Loss:  55.9818752245  chars  1180000/2108622  ==============
# xithy if ou thou cho pralwel theecind tag 	lodyy.]
# 	[ufe hifld erervit.
# 	I wuntu
# 	thur inet orott nad
# ========== Iteration  473  Loss:  56.1159792326  chars  1182500/2108622  ==============
# Lar VwMat I
# 	To so letve nesesbejn foulliefine!	; trereech old ceilded iiss to goving lithe sgean, fi
# ========== Iteration  474  Loss:  56.0365314918  chars  1185000/2108622  ==============
# -ravas;
# 	in in
# 	Souast
# 	fangenie. in?
# 	Thivh ride	tut itd onle I
# 	at he as ath musevor: corishis be.
#
# ========== Iteration  475  Loss:  55.8944928678  chars  1187500/2108622  ==============
# reens.
#
# LIPTIN!O PRINER
# PENE PEO I IO OO LEO	I I that se mank wu thour seramean.
#
# NANTREDIA	Whell and
# ========== Iteration  476  Loss:  55.8830836243  chars  1190000/2108622  ==============
# :
# 	s for houn: I badbere.
#
# DObey Isher I d, you iit doyin' tinld as net hich.
#
# WEV-ONDEL	IN bop a gou
# ========== Iteration  477  Loss:  55.8269288895  chars  1192500/2108622  ==============
# )th Rifsh, m you sie seet of wade domked thind sodl, fin
# 	oubb by hecime
#
#
# RENOA	And ath NTins oomd a
# ========== Iteration  478  Loss:  55.9222351015  chars  1195000/2108622  ==============
# Lw? CUCED	Qodove, d, one fow shath ghakapcinftt woech unche snouns.
#
# DONTheT	Poucky bien wermil:
# 	lof
# ========== Iteration  479  Loss:  56.1570438822  chars  1197500/2108622  ==============
# Phee ta e he youlount catace sor Lhe roppandonvas me tous Bory the lavesd comege mutha reart in yoy a
# ========== Iteration  480  Loss:  56.0748197392  chars  1200000/2108622  ==============
# (m beisde forend nof of
# 	Ia dispyourt hart, hhe mance: ve. oog thas mull bakcnpfand che on he fove no
# ========== Iteration  481  Loss:  56.2154107108  chars  1202500/2108622  ==============
#  Ot. Ther
# 	Iy the mey or mogiss,-s
# 	wirpusess an
#
# SAktREDN SR IRO	I mithe senless wy cer
# 	siik wit ve
# ========== Iteration  482  Loss:  56.2211883982  chars  1205000/2108622  ==============
# im Qolm co, heu patt at so me thee you fore-dincant?
#
# BsACBAEN	Wheose' gherunt andon or un the dath'g
# ========== Iteration  483  Loss:  56.1060628522  chars  1207500/2108622  ==============
# kengu; the weat thes. DI wimet
# 	Fy I hiy
# 	Lorsandy ait hert'd wer pnof marcondd; O thalk meoccy.
#
# DER
# ========== Iteration  484  Loss:  56.1528863205  chars  1210000/2108622  ==============
# xtatny.
#
# QYEVEELI	Gilime mor besthan
# 	mich bat eras; me, bame shousrit?
#
# BOYTRRIL	Herlet.
#
# 	[Tr: INAN
# ========== Iteration  485  Loss:  56.0525317422  chars  1212500/2108622  ==============
# ey Yomu ar to hith aranach:
# 	Te vaply eid thould sonent ardss op wiin anssobrfuul thas that Qinnt, I
# ========== Iteration  486  Loss:  55.9469689032  chars  1215000/2108622  ==============
# , hewesin bome, nothy un and cove dine o hag niy urice fhaspertise, you hid thy ages endarats.
#
# OTDRA
# ========== Iteration  487  Loss:  55.7270518578  chars  1217500/2108622  ==============
# T] Call retadhe be mon pertoll uraly yao ber ta soce
# 	Latinna plane and and
# 	burhis hincen ie,
# 	Egans
# ========== Iteration  488  Loss:  55.8266589098  chars  1220000/2108622  ==============
# -xipunw lott
#
# COWKIRME	GT yive sheres no- as rissc af lomt, Co vall aaco beve roof eneind. HO wee ear
# ========== Iteration  489  Loss:  55.9380323683  chars  1222500/2108622  ==============
# OD	Suate, hof Fet the
# 	whas Hore tha, ane klade il inet.
#
# LODNARBO: E O to ADDIA I RAREC	Whit me vith
# ========== Iteration  490  Loss:  55.8707029871  chars  1225000/2108622  ==============
# PI
# 	Yheamet:
#
# CERAIMC CTtERTK A PHECRO
# 	E leimise ie hiy t im fom hy y the, his wot well sthimlen! I
# ========== Iteration  491  Loss:  55.7541474155  chars  1227500/2108622  ==============
# I
# 	Cedvest, fort as erthe sporpent me lpuagay ur pavet; Wonled, I I yha  het you coor; BEtwank I w'lg
# ========== Iteration  492  Loss:  55.9368838133  chars  1230000/2108622  ==============
# y,
#
# BENDRRIRTO
#
#
# DHECENIO	Pry letor, fuspyof reseapnite.
#
# CANCILUT]	Ar we winld; so gea fhoud, hryen
# ========== Iteration  493  Loss:  55.8188647407  chars  1232500/2108622  ==============
# xth the weomens, sull ad, ind lo
#
#
# DE
# DOCA	Wway we fam Lfinl nod ild hick and Ip an muall yuth pret h
# ========== Iteration  494  Loss:  55.6977177459  chars  1235000/2108622  ==============
# jat: bet urays ayku hith lilland, ciipowe
# 	now of thil  non, shith pebide lofeeve.
#
# GABkRUSDO	Ce tham
# ========== Iteration  495  Loss:  55.6795516388  chars  1237500/2108622  ==============
# pebermres wer shou shind,cis?
#
# BEve bLRNO	The notn cait py in mame righ attin  faron hereit I mam, co
# ========== Iteration  496  Loss:  55.7678497874  chars  1240000/2108622  ==============
# Kr?	I'mt pere
#
#
# PAARI	IO I An I ilagt netilo the prame dhal ;no co ond hems noud not sh thine, Omn hi
# ========== Iteration  497  Loss:  55.6407462776  chars  1242500/2108622  ==============
#
# 	Cest and ther nocpepeeres shen will thir, dod wallls, loocere seshod: ther wiswe,
# 	To tyou fereyece
# ========== Iteration  498  Loss:  55.6882267745  chars  1245000/2108622  ==============
# d, Bowe stous wime ald enoth hat imm that hes ind ond lode dout ig momanit and Arly thave.
#
# ROUR
#
# O	A
# ========== Iteration  499  Loss:  55.468419623  chars  1247500/2108622  ==============
# und.
# 	Thou bers:
# 	Merurt, shet wher shert hit I eremes to lllate whe ben sile lus theas the lall a in
# ========== Iteration  500  Loss:  55.4404687608  chars  1250000/2108622  ==============
# xsur;
# 	guchy w theerurtente trees,
# 	Thaw an the hele bfisyor.
#
# CONESNIRD	Thor sfllisland
# 	gher mika n
# ========== Iteration  501  Loss:  56.1447047728  chars  1252500/2108622  ==============
# |PCimg DACAC]	Acis I hind
# 	too will thich.
#
# 	[Ed ey deas othre metd doxchasm; byap ander,
# 	White too
# ========== Iteration  502  Loss:  56.1783648649  chars  1255000/2108622  ==============
# x? hat Im I barwiung, coyke dore.
#
# DIDSOI Oy I binst
# 	Mer?
#
# CEAPTANI
# 	Anv llin,
# 	Here ath, I nome the
# ========== Iteration  503  Loss:  56.0615582823  chars  1257500/2108622  ==============
# xptang;
# 	and the yous cive balle'd, yove
# 	hine: In aod ir way wove fmo cutne hot at? Bouf ord the, on
# ========== Iteration  504  Loss:  55.8881006264  chars  1260000/2108622  ==============
# P	[ronk nu, siot'ch, Fon.
# 	Wo and wenor andiminns wo siast verer.
# 	minelr Sterve fove
# 	I at neus.
# 	Ho
# ========== Iteration  505  Loss:  55.9246241676  chars  1262500/2108622  ==============
# Sasanc hadlt ghinl of serthe
# 	tur, I lould, mylupy, sp
# CyRt tiny OS ONan, BHILNCE	Thou somi hirn fhas
# ========== Iteration  506  Loss:  55.8581755323  chars  1265000/2108622  ==============
# xess
# 	Hpit, ino meve dero; IO llond Ilalligo:RC
# DEENHENA DEODTACE	be uis thy wher: mece yof -minp cou
# ========== Iteration  507  Loss:  55.8134217091  chars  1267500/2108622  ==============
# |Nders I math? I lpuast saghat,
# 	No siy I atl the leyperr thle st ip dibt onote chappereacy:if? she b
# ========== Iteration  508  Loss:  55.9456087994  chars  1270000/2108622  ==============
# kull Bindto-'skor-
#
# THOCATI	Cove haath sedartd, are se at eis Menie, s alleut bo
# 	Acpsavest coptuy
# 	f
# ========== Iteration  509  Loss:  55.8061852915  chars  1272500/2108622  ==============
# ]
#
# PERTCE
# 	Brd how mit
#  Marethund da
#
#
# CoxnwR	Whou:
#
# LLSEEA	Ho prove | bucloel! and and trith.
# 	Houe
# ========== Iteration  510  Loss:  55.8288023235  chars  1275000/2108622  ==============
# :
# 	Then; and theres; Gy vask: gracion'llgmas.
# 	Seeissorisfu.
#
# CFANCE	I as ot
# 	And enctyssee kecglon?
#
# ========== Iteration  511  Loss:  55.912813574  chars  1277500/2108622  ==============
# NAMand is mindngun Fan I hinge nor: go tir thed blnterert'vir', beis. whet yol mbithese waly uthy nou
# ========== Iteration  512  Loss:  55.9105477044  chars  1280000/2108622  ==============
# Q.
# 	[Evet Disneng-	DE inde,
# 	Srany wos whind pttully finte, thand wambos
# 	ir owy raddieg thir saras E
# ========== Iteration  513  Loss:  55.8934581155  chars  1282500/2108622  ==============
# le, Is no it file camelr alt thy wil toribe.
#
# LERLECACA	Nat llang.
#
# HTLACL]A	se theebast
# 	Ard arttin
# ========== Iteration  514  Loss:  56.1508545397  chars  1285000/2108622  ==============
# zeZy sertape,
# 	Ines, clamat dies all:
# 	Nerife nok ste, whem I wnof nos chathe doth heracs and
# 	Gtald
# ========== Iteration  515  Loss:  56.2676085977  chars  1287500/2108622  ==============
# I fle essr.d
# 	Mxou hannyous, che ive, sabcer conete weus d ausl te the thiuge
# 	bo doy and nowh bot, I
# ========== Iteration  516  Loss:  56.1603174475  chars  1290000/2108622  ==============
# Cqaren hor Jagn.
#
# BEITUI
# 	Til thit themer
# 	Hong pave?
#
# DOE FERISON HAIT HRKAES	NEge Illle, IoL IOS
#
# C
# ========== Iteration  517  Loss:  56.0269628844  chars  1292500/2108622  ==============
# snder at lerine	ur ins; Pualy br mneallce!	Bun tiee.
#
# 	AnRB]ACENDCES
# 	Amcist.
#
# BEREMIS
# 	SL OSI ANlEON
# ========== Iteration  518  Loss:  56.0204490937  chars  1295000/2108622  ==============
# ) Anllker your;sithi; on unrere, m sall'be.
# 	Ga beven.
#
#
#
# BERERCO	curcHteresend then, of h 	woovisen
#
# ========== Iteration  519  Loss:  56.0404436145  chars  1297500/2108622  ==============
# Ant winghe, rapy lulverdong,
# 	Her youdund,
# 	Fitre:
# 	Ipaill yould fr mell tulltic!
# 	Hirkersnicgfemur t
# ========== Iteration  520  Loss:  55.9829472618  chars  1300000/2108622  ==============
# ro,; Yoly in
# 	Ants your ming ilgtef, bedeels ef somes pele salusg bey ind whrer live; thiy u; pulgwe
#
# ========== Iteration

# %%
hallucinate(sess, random.randint(0,vocab_size-1), 1000)

# %%
# RunModel()
